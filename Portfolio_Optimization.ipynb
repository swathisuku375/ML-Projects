# %% [markdown]
# #Data Prep and EDA

# %% [markdown]
# ##  1. Prepare the Data

# %%
#We import modules for data wrangling and analysis
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import *

# %%
# packages needed to call Yahoo finance API and load stocks
# !pip install yahoo_fin
# !pip install requests_html
import yahoo_fin.stock_info as si
# Out:
# Collecting yahoo_fin
#   Downloading yahoo_fin-0.8.9.1-py3-none-any.whl (10 kB)
# Collecting requests-html
#   Downloading requests_html-0.10.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (2.23.0)
# Collecting feedparser
#   Downloading feedparser-6.0.8-py3-none-any.whl (81 kB)
#      |████████████████████████████████| 81 kB 5.6 MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (1.3.5)
# Collecting sgmllib3k
#   Downloading sgmllib3k-1.0.0.tar.gz (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (1.21.6)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2022.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2.10)
# Collecting pyppeteer>=0.0.14
#   Downloading pyppeteer-1.0.2-py3-none-any.whl (83 kB)
#      |████████████████████████████████| 83 kB 1.9 MB/s
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.0.1)
# Collecting fake-useragent
#   Downloading fake-useragent-0.1.11.tar.gz (13 kB)
# Collecting parse
#   Downloading parse-1.19.0.tar.gz (30 kB)
# Collecting w3lib
#   Downloading w3lib-1.22.0-py2.py3-none-any.whl (20 kB)
# Collecting pyquery
#   Downloading pyquery-1.4.3-py3-none-any.whl (22 kB)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Collecting pyee<9.0.0,>=8.1.0
#   Downloading pyee-8.2.2-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.64.0)
# Collecting websockets<11.0,>=10.0
#   Downloading websockets-10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (112 kB)
#      |████████████████████████████████| 112 kB 60.2 MB/s
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.11.3)
# Collecting urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 73.0 MB/s
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html->yahoo_fin) (4.6.3)
# Collecting cssselect>0.7.9
#   Downloading cssselect-1.1.0-py2.py3-none-any.whl (16 kB)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (4.2.6)
# Building wheels for collected packages: fake-useragent, parse, sgmllib3k
#   Building wheel for fake-useragent (setup.py) ... done
#   Created wheel for fake-useragent: filename=fake_useragent-0.1.11-py3-none-any.whl size=13502 sha256=f8ca767a9f6bc1773a79d48cf51da696b67ec6729319cf9d735541eda97059d5
#   Stored in directory: /root/.cache/pip/wheels/ed/f7/62/50ab6c9a0b5567267ab76a9daa9d06315704209b2c5d032031
#   Building wheel for parse (setup.py) ... done
#   Created wheel for parse: filename=parse-1.19.0-py3-none-any.whl size=24591 sha256=e10407cd19c8f7ef3cbd192e9555d2a1d6dd519c80ccf95c3e77f06cb3c23e6b
#   Stored in directory: /root/.cache/pip/wheels/9c/aa/cc/f2228050ccb40f22144b073f15a2c84f11204f29fc0dce028e
#   Building wheel for sgmllib3k (setup.py) ... done
#   Created wheel for sgmllib3k: filename=sgmllib3k-1.0.0-py3-none-any.whl size=6066 sha256=8b362f14bae297ee48ac0a3a4f5b7f3d96598c5e280c33eea2845d17ef98bc2c
#   Stored in directory: /root/.cache/pip/wheels/73/ad/a4/0dff4a6ef231fc0dfa12ffbac2a36cebfdddfe059f50e019aa
# Successfully built fake-useragent parse sgmllib3k
# Installing collected packages: websockets, urllib3, pyee, cssselect, w3lib, sgmllib3k, pyquery, pyppeteer, parse, fake-useragent, requests-html, feedparser, yahoo-fin
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed cssselect-1.1.0 fake-useragent-0.1.11 feedparser-6.0.8 parse-1.19.0 pyee-8.2.2 pyppeteer-1.0.2 pyquery-1.4.3 requests-html-0.10.0 sgmllib3k-1.0.0 urllib3-1.25.11 w3lib-1.22.0 websockets-10.3 yahoo-fin-0.8.9.1
# Requirement already satisfied: requests_html in /usr/local/lib/python3.7/dist-packages (0.10.0)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.4.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from requests_html) (2.23.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests_html) (0.0.1)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.0.2)
# Requirement already satisfied: parse in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.19.0)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from requests_html) (0.1.11)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.22.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: certifi>=2021 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (2021.10.8)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (10.3)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (1.25.11)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (4.64.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (4.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests_html) (4.6.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests_html) (4.2.6)
# Requirement already satisfied: cssselect>0.7.9 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests_html) (1.1.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->requests_html) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->requests_html) (2.10)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from w3lib->requests_html) (1.15.0)

# %% [markdown]
# **Stocks**
#
# Market Cap requirement : <= $2 Billion:
#
# <br>
#
# The Stocks we have chosen as per our requirement are :
#
# <br>
#
# **AITX** :Artificial Intelligence Technology Solutions Inc.  <br>
#           Market Cap at time of analysis:	66.112M<br>
#           https://finance.yahoo.com/quote/AITX?p=AITX
#
# <BR>
#
# **NVTA** : Invitae Corporation<br>
#        Market Cap at time of analysis:	1.578B<br>
#        https://finance.yahoo.com/quote/NVTA?p=NVTA<br><br>
#
# **TVTY** : Tivity Health, Inc.<br>
#        Market Cap at time of analysis:	1.612B<br>
#        https://finance.yahoo.com/quote/TVTY?p=TVTY<br><br>
#
# **ERBB** : American Green, Inc.<br>
#          Market Cap at time of analysis:	110.031M<br>
#          https://finance.yahoo.com/quote/ERBB?p=ERBB

# %% [markdown]
# **CryptoCurrencies**
#
# Market Cap requirement : $20Billion to 40Billion :
# <BR>
# <BR>
# The Cryptocurrencies we have chosen as per our requirement are :
#
# **LUNA** : Terra<BR>
#        Market Cap $30,674,471,693<BR>
#        https://coinmarketcap.com/currencies/terra-luna/
# <BR><BR>
#
# **SOL**: Solana<BR>
# Market Cap<BR>
# $33,762,249,079<BR>
# https://coinmarketcap.com/currencies/solana/
# <BR><BR>
#
# **UST**: TerraUSD<BR>
#       Market Cap $16,746,294,872<BR>
#       https://coinmarketcap.com/currencies/terrausd/
# <BR><BR>
#
#
# **LTC** : Litecoin<BR>
# Market Cap<BR>
# $7,334,897,793 <BR>
# https://coinmarketcap.com/currencies/litecoin/<BR>
#
# Note that UST and LCT Cryptocurrecies were chosen out of our required Market Cap bracket, since we had unsatisfactory data for the rest of the Cryptocurrencies fitting the Market cap. Details explained below.

# %% [markdown]
# Upon filtering for cryptocurrencies in the 20Billion to 40Billion range, we are left with 5 Cryptocurrecies, as shown in the image.
#
#
#
# ![Stockscrypto.png](data:image/png;base64,...)

# %% [markdown]
# For the Cryptocurrencies XRP, ADA and HEX we face the following issues :

# %%
# 1 : XRP
#from yahoo_fin.stock_info import get_data
#xrp= get_data("XRP", start_date="01/01/2016", end_date="12/31/2020", index_as_date = True, interval="1d")

#We get a timestamp error while loading data since the API does not fetch 1 day interval data for XRP. Hence, we excluded XRP from our analysis.

# %%
# 2 : Cardano ADA
from yahoo_fin.stock_info import get_data
ada= get_data("ADA", start_date="01/01/2016", end_date="12/31/2020", index_as_date = True, interval="1d")
print("The returned ADA Data frame has ",ada.shape[0],"rows and ",ada.shape[1]," columns.")
#There are 523 rows but there is no variation in the data. All 523 rows have the same value of 2.13.
# Out:
# The returned ADA Data frame has  1258 rows and  7  columns.

# %%
#Out of the 1258 rows, 735 are missing values which leaves us 523 non-null rows.
ada.isnull().sum()
# Out:
# open        735
# high        735
# low         735
# close       735
# adjclose    735
# volume      735
# ticker        0
# dtype: int64

# %%
#On further analysis, we saw that all 523 rows had the same value and the data had no variation. Hence, we excluded ADA Crptocurrency from our analysis.
print(ada.value_counts())
# Out:
# open  high  low   close  adjclose  volume  ticker
# 2.13  2.13  2.13  2.13   2.13      0.0     ADA       523
# dtype: int64

# %%
# 3 : HEX
from yahoo_fin.stock_info import get_data
hex= get_data("HEX", start_date="01/01/2016", end_date="12/31/2020", index_as_date = True, interval="1d")
hex.info()
#The data returns only 1 Non-Null row. Hence, we exclude HEX from our list of cryptocurrency candidates.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1242 entries, 2016-01-27 to 2020-12-30
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   open      1 non-null      float64
#  1   high      1 non-null      float64
#  2   low       1 non-null      float64
#  3   close     1 non-null      float64
#  4   adjclose  1 non-null      float64
#  5   volume    1 non-null      float64
#  6   ticker    1242 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 77.6+ KB

# %% [markdown]
# Hence for the above mentioned reasons, we excluded HEX, ADA and XRP from our analysis and proceeded with LUNA, SOL, LTC, UST as our cryptocurrency candidates for our analysis.

# %%
# Assign the ticker list of stocks and cryptocurrencies that we want to scrap
tickers_list = ['NVTA','AITX','TVTY','ERBB','UST','LUNA','SOL','LTC']
# pull historical price data for each item in the tickers_list between the start and end data in 1 day intervals.
dow_prices = {ticker : si.get_data(ticker,start_date = '01/01/2016',end_date='12/31/2020',interval='1d') for ticker in tickers_list}

#  2020-12-24  10.00  10.58   9.68   9.70      9.70  3480700    SOL
#  2020-12-28  10.00  12.55   9.93  12.50     12.50  9407100    SOL
#  2020-12-29  11.15  12.70  10.34  12.23     12.23  5943100    SOL
#  2020-12-30  12.50  13.20  11.53  11.68     11.68  9339100    SOL
#
#  [1258 rows x 7 columns],
#  'TVTY':                  open       high        low      close   adjclose  volume  \
#  2016-01-04  12.680000  12.930000  12.460000  12.810000  12.810000  249400
#  2016-01-05  12.900000  13.070000  12.830000  12.900000  12.900000  158500
#  2016-01-06  12.770000  13.260000  12.750000  13.190000  13.190000  326400
#  2016-01-07  13.050000  13.150000  12.910000  13.020000  13.020000  268000
#  2016-01-08  13.090000  13.270000  12.640000  12.680000  12.680000  262000
#  ...               ...        ...        ...        ...        ...     ...
#  2020-12-23  19.049999  19.590000  19.049999  19.410000  19.410000  202800
#  2020-12-24  19.520000  19.750000  19.270000  19.600000  19.600000   87900
#  2020-12-28  19.820000  20.170000  19.389999  19.410000  19.410000  276900
#  2020-12-29  19.240000  19.860001  18.920000  19.049999  19.049999  331500
#  2020-12-30  19.270000  20.090000  19.270000  19.610001  19.610001  214300
#
#             ticker
#  2016-01-04   TVTY
#  2016-01-05   TVTY
#  2016-01-06   TVTY
#  2016-01-07   TVTY
#  2016-01-08   TVTY
#  ...           ...
#  2020-12-23   TVTY
#  2020-12-24   TVTY
#  2020-12-28   TVTY
#  2020-12-29   TVTY
#  2020-12-30   TVTY
#
#  [1258 rows x 7 columns],
#  'UST':                  open       high        low      close   adjclose  volume  \
#  2016-01-04  56.619999  56.869999  56.520000  56.580002  53.684185  185300
#  2016-01-05  56.400002  56.680000  56.400002  56.529999  53.636734    8200
#  2016-01-06  56.930000  57.200001  56.930000  57.200001  54.272457    8700
#  2016-01-07  57.340000  57.439999  57.049999  57.410000  54.471706   15600
#  2016-01-08  57.270000  57.810001  57.270000  57.779999  54.822762   45400
#  ...               ...        ...        ...        ...        ...     ...
#  2020-12-23  73.139999  73.320000  73.139999  73.250000  73.097404   17100
#  2020-12-24  73.449997  73.480003  73.430000  73.459999  73.306961    3500
#  2020-12-28  73.260002  73.550003  73.260002  73.550003  73.396782    4000
#  2020-12-29  73.379997  73.529999  73.379997  73.529999  73.376816    1000
#  2020-12-30  73.459999  73.589996  73.459999  73.570000  73.416740   19300
#
#             ticker
#  2016-01-04    UST
#  2016-01-05    UST
#  2016-01-06    UST
#  2016-01-07    UST
#  2016-01-08    UST
#  ...           ...
#  2020-12-23    UST
#  2020-12-24    UST
#  2020-12-28    UST
#  2020-12-29    UST
#  2020-12-30    UST
#
#  [1258 rows x 7 columns]}

# %%
# We extract 'adjclose' price column data for the first sample NVTA to serve as a skelton to add the rest of the stocks and cryptocurrencies (tickers).
prep_data = pd.DataFrame(dow_prices['NVTA']['adjclose']).rename(columns = {"adjclose":"NVTA"})

# Adding all the tickers to the prep_data data frame
for i in tickers_list[1:]:
  prep_data[i] = pd.DataFrame(dow_prices[i]['adjclose'])
# prep_data

# %%
#adjusted close prices for all stocks and cryptocurrecies :
prep_data.head()
# Out:
#             NVTA      AITX   TVTY  ERBB        UST  LUNA   SOL        LTC
# 2016-01-04  7.30  190000.0  12.81  1.00  53.684185  1.06  9.10  30.539497
# 2016-01-05  7.46  210000.0  12.90  0.95  53.636734  1.12  8.90  31.668995
# 2016-01-06  7.28  210000.0  13.19  0.90  54.272457  1.09  9.05  31.363544
# 2016-01-07  7.01  160000.0  13.02  0.90  54.471706  1.04  8.45  30.795223
# 2016-01-08  7.52  200000.0  12.68  0.80  54.822762  1.00  8.50  30.582104

# %%
prep_data.info()
#We have consistent 1258 Non-null values for all our tickers
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1258 entries, 2016-01-04 to 2020-12-30
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NVTA    1258 non-null   float64
#  1   AITX    1258 non-null   float64
#  2   TVTY    1258 non-null   float64
#  3   ERBB    1258 non-null   float64
#  4   UST     1258 non-null   float64
#  5   LUNA    1258 non-null   float64
#  6   SOL     1258 non-null   float64
#  7   LTC     1258 non-null   float64
# dtypes: float64(8)
# memory usage: 88.5 KB

# %%
#1258 rows and 8 columns in the dataframe
prep_data.shape
# Out:
# (1258, 8)

# %%
prep_data.isnull().sum()
#There are no missing values in any of the tickers
# Out:
# NVTA    0
# AITX    0
# TVTY    0
# ERBB    0
# UST     0
# LUNA    0
# SOL     0
# LTC     0
# dtype: int64

# %%
# create return features for each ticker :
return_data = pd.DataFrame()

for i in tickers_list:
#pct_change : Percentage change between the current and a prior element.
#we get simple returns for each day for each ticker.
  return_data[i] = prep_data[i].pct_change()
  
# drop the na records
return_data.dropna(inplace=True)
return_data
# Out:
#                 NVTA      AITX      TVTY      ERBB       UST      LUNA  \
# 2016-01-05  0.021918  0.105263  0.007026 -0.050000 -0.000884  0.056604
# 2016-01-06 -0.024129  0.000000  0.022481 -0.052632  0.011852 -0.026786
# 2016-01-07 -0.037088 -0.238095 -0.012888  0.000000  0.003671 -0.045872
# 2016-01-08  0.072753  0.250000 -0.026114 -0.111111  0.006445 -0.038462
# 2016-01-11 -0.035904  0.000000 -0.026814 -0.062500 -0.007269  0.020000
# ...              ...       ...       ...       ...       ...       ...
# 2020-12-23 -0.039375  0.504237  0.023734  1.370370 -0.004891  0.111801
# 2020-12-24 -0.076878  0.816901  0.009789 -0.218750  0.002867 -0.077281
# 2020-12-28 -0.034417  0.930233 -0.009694 -0.200000  0.001225 -0.001009
# 2020-12-29 -0.033223  0.004016 -0.018547  0.275000 -0.000272 -0.033333
# 2020-12-30  0.005917  0.738000  0.029396 -0.137255  0.000544  0.007315
#
#                  SOL       LTC
# 2016-01-05 -0.021978  0.036985
# 2016-01-06  0.016854 -0.009645
# 2016-01-07 -0.066298 -0.018120
# 2016-01-08  0.005917 -0.006921
# 2016-01-11 -0.029412  0.011150
# ...              ...       ...
# 2020-12-23 -0.191667 -0.004347
# 2020-12-24  0.000000  0.006420
# 2020-12-28  0.288660  0.005614
# 2020-12-29 -0.021600 -0.008120
# 2020-12-30 -0.044971 -0.010489
#
# [1257 rows x 8 columns]

# %%
# Print the shape of data
return_data.shape
# Out:
# (1257, 8)

# %%
# Print the info of data set
return_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1257 entries, 2016-01-05 to 2020-12-30
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   NVTA    1257 non-null   float64
#  1   AITX    1257 non-null   float64
#  2   TVTY    1257 non-null   float64
#  3   ERBB    1257 non-null   float64
#  4   UST     1257 non-null   float64
#  5   LUNA    1257 non-null   float64
#  6   SOL     1257 non-null   float64
#  7   LTC     1257 non-null   float64
# dtypes: float64(8)
# memory usage: 88.4 KB

# %% [markdown]
# ## Visualize the Time Series

# %%
#Plot all ticker data i.e. my returns to see distribution
return_data.plot(subplots=True,
        grid=True, 
        layout=(3,4),
         figsize=(15,15))
#Print the plot
plt.show()

# %%
# Calculate the cumulative daily returns using pandas cumprod function
df_cum_daily_returns = (1 + return_data).cumprod() - 1
df_cum_daily_returns = df_cum_daily_returns.reset_index()
# Display the cumulative daily returns
df_cum_daily_returns
# Out:
#           index      NVTA      AITX      TVTY    ERBB       UST      LUNA  \
# 0    2016-01-05  0.021918  0.105263  0.007026 -0.0500 -0.000884  0.056604
# 1    2016-01-06 -0.002740  0.105263  0.029664 -0.1000  0.010958  0.028302
# 2    2016-01-07 -0.039726 -0.157895  0.016393 -0.1000  0.014670 -0.018868
# 3    2016-01-08  0.030137  0.052632 -0.010148 -0.2000  0.021209 -0.056604
# 4    2016-01-11 -0.006849  0.052632 -0.036690 -0.2500  0.013786 -0.037736
# ...         ...       ...       ...       ...     ...       ...       ...
# 1252 2020-12-23  5.984932 -1.000000  0.515222 -0.9936  0.361619  9.132076
# 1253 2020-12-24  5.447945 -1.000000  0.530055 -0.9950  0.365522  8.349057
# 1254 2020-12-28  5.226027 -1.000000  0.515222 -0.9960  0.367196  8.339623
# 1255 2020-12-29  5.019178 -1.000000  0.487119 -0.9949  0.366824  8.028302
# 1256 2020-12-30  5.054794 -1.000000  0.530835 -0.9956  0.367567  8.094340
#
#            SOL       LTC
# 0    -0.021978  0.036985
# 1    -0.005495  0.026983
# 2    -0.071429  0.008374
# 3    -0.065934  0.001395
# 4    -0.093407  0.012561
# ...        ...       ...
# 1252  0.065934  0.174696
# 1253  0.065934  0.182238
# 1254  0.373626  0.188875
# 1255  0.343956  0.179221
# 1256  0.283516  0.166853
#
# [1257 rows x 9 columns]

# %%
#Plotting cumulative daily returns
dailyreturnplot=df_cum_daily_returns.copy()
dailyreturnplot=dailyreturnplot.set_index('index')
dailyreturnplot=dailyreturnplot*100
#Plot, Label and print the graph
dailyreturnplot.plot()
plt.xlabel('Year')
plt.ylabel('Cumulative daily return')
plt.show()

# %%
#Last record of dataframe multiplied by 100 is giving us the percentage change of the stock prices for our entire period, as shown below
cum_return_entire_period = df_cum_daily_returns.iloc[:, 1:].tail(1)
cum_return_entire_period * 100
# Out:
#             NVTA       AITX       TVTY   ERBB        UST        LUNA  \
# 1256  505.479447 -99.999977  53.083528 -99.56  36.756738  809.434044
#
#             SOL        LTC
# 1256  28.351646  16.685291

# %% [markdown]
# # Optimization Model

# %%
# before you do anything...
# mount your drive!
# click folder on the left...
# import modules

# import modules
import pandas as pd
import numpy as np
from pylab import * 
import shutil
import sys
import os.path

if not shutil.which("pyomo"):
    # !pip install -q pyomo
    assert(shutil.which("pyomo"))

if not (shutil.which("bonmin") or os.path.isfile("bonmin")):
    if "google.colab" in sys.modules:
        # !wget -N -q "https://ampl.com/dl/open/bonmin/bonmin-linux64.zip"
        # !unzip -o -q bonmin-linux64
        # !apt-get install -y -qq mindtpy
    else:
        try:
            # !conda install -c conda-forge ipopt
        except:
            pass

assert(shutil.which("bonmin") or os.path.isfile("bonmin"))

# This is how you should setup the SolverFactory command to use Bonmin
# SolverFactory('bonmin', executable='/content/bonmin')

from pyomo.environ import *


# some stock-specific packages
# !pip install yahoo_fin
# !pip install requests_html
import yahoo_fin.stock_info as si
# Out:
#      |████████████████████████████████| 9.6 MB 6.0 MB/s
#      |████████████████████████████████| 49 kB 3.1 MB/s
# Requirement already satisfied: yahoo_fin in /usr/local/lib/python3.7/dist-packages (0.8.9.1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (1.3.5)
# Requirement already satisfied: requests-html in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (0.10.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (2.23.0)
# Requirement already satisfied: feedparser in /usr/local/lib/python3.7/dist-packages (from yahoo_fin) (6.0.8)
# Requirement already satisfied: sgmllib3k in /usr/local/lib/python3.7/dist-packages (from feedparser->yahoo_fin) (1.0.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (2022.1)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.7/dist-packages (from pandas->yahoo_fin) (1.21.6)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->yahoo_fin) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2021.10.8)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (1.25.11)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->yahoo_fin) (3.0.4)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.22.0)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.0.2)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.0.1)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (0.1.11)
# Requirement already satisfied: parse in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.19.0)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.7/dist-packages (from requests-html->yahoo_fin) (1.4.3)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (8.2.2)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (10.3)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.11.3)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (1.4.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.64.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests-html->yahoo_fin) (4.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests-html->yahoo_fin) (4.6.3)
# Requirement already satisfied: cssselect>0.7.9 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (1.1.0)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests-html->yahoo_fin) (4.2.6)
# Requirement already satisfied: requests_html in /usr/local/lib/python3.7/dist-packages (0.10.0)
# Requirement already satisfied: bs4 in /usr/local/lib/python3.7/dist-packages (from requests_html) (0.0.1)
# Requirement already satisfied: fake-useragent in /usr/local/lib/python3.7/dist-packages (from requests_html) (0.1.11)
# Requirement already satisfied: pyquery in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.4.3)
# Requirement already satisfied: pyppeteer>=0.0.14 in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.0.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from requests_html) (2.23.0)
# Requirement already satisfied: w3lib in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.22.0)
# Requirement already satisfied: parse in /usr/local/lib/python3.7/dist-packages (from requests_html) (1.19.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (4.11.3)
# Requirement already satisfied: appdirs<2.0.0,>=1.4.3 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (1.4.4)
# Requirement already satisfied: urllib3<2.0.0,>=1.25.8 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (1.25.11)
# Requirement already satisfied: websockets<11.0,>=10.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (10.3)
# Requirement already satisfied: certifi>=2021 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (2021.10.8)
# Requirement already satisfied: tqdm<5.0.0,>=4.42.1 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (4.64.0)
# Requirement already satisfied: pyee<9.0.0,>=8.1.0 in /usr/local/lib/python3.7/dist-packages (from pyppeteer>=0.0.14->requests_html) (8.2.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->pyppeteer>=0.0.14->requests_html) (4.2.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.7/dist-packages (from bs4->requests_html) (4.6.3)
# Requirement already satisfied: lxml>=2.1 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests_html) (4.2.6)
# Requirement already satisfied: cssselect>0.7.9 in /usr/local/lib/python3.7/dist-packages (from pyquery->requests_html) (1.1.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->requests_html) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->requests_html) (3.0.4)
# Requirement already satisfied: six>=1.4.1 in /usr/local/lib/python3.7/dist-packages (from w3lib->requests_html) (1.15.0)

# %%
#Visualize past returns of all tickers
return_data.plot()
plt.xlabel('Year')
plt.ylabel('Daily simple returns (%)')
plt.show()
#we get simple returns for each day for each ticker.

# %%
# Print the first few rows of the data
return_data.head()
# Out:
#                 NVTA      AITX      TVTY      ERBB       UST      LUNA  \
# 2016-01-05  0.021918  0.105263  0.007026 -0.050000 -0.000884  0.056604
# 2016-01-06 -0.024129  0.000000  0.022481 -0.052632  0.011852 -0.026786
# 2016-01-07 -0.037088 -0.238095 -0.012888  0.000000  0.003671 -0.045872
# 2016-01-08  0.072753  0.250000 -0.026114 -0.111111  0.006445 -0.038462
# 2016-01-11 -0.035904  0.000000 -0.026814 -0.062500 -0.007269  0.020000
#
#                  SOL       LTC
# 2016-01-05 -0.021978  0.036985
# 2016-01-06  0.016854 -0.009645
# 2016-01-07 -0.066298 -0.018120
# 2016-01-08  0.005917 -0.006921
# 2016-01-11 -0.029412  0.011150

# %%
# covariance matrix
Covariance_matrix = return_data.cov()
Covariance_matrix
# Display the covariance matrix
Covariance_matrix.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_c6c86_row0_col0, #T_c6c86_row1_col1, #T_c6c86_row2_col2, #T_c6c86_row3_col3, #T_c6c86_row4_col4, #T_c6c86_row5_col5, #T_c6c86_row6_col6, #T_c6c86_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c6c86_row0_col1, #T_c6c86_row2_col1, #T_c6c86_row6_col1 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_c6c86_row0_col2, #T_c6c86_row4_col7 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_c6c86_row0_col3, #T_c6c86_row2_col3, #T_c6c86_row6_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_c6c86_row0_col4, #T_c6c86_row0_col5, #T_c6c86_row2_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_c6c86_row0_col6, #T_c6c86_row5_col2 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_c6c86_row0_col7 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_c6c86_row1_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_c6c86_row1_col2 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_c6c86_row1_col3, #T_c6c86_row1_col5, #T_c6c86_row1_col7, #T_c6c86_row3_col1, #T_c6c86_row3_col4, #T_c6c86_row4_col0, #T_c6c86_row4_col2, #T_c6c86_row4_col6 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c6c86_row1_col4 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_c6c86_row1_col6 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_c6c86_row2_col4, #T_c6c86_row5_col4 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_c6c86_row2_col5 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_c6c86_row2_col6 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_c6c86_row2_col7 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_c6c86_row3_col0, #T_c6c86_row4_col3 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_c6c86_row3_col2 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_c6c86_row3_col5 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_c6c86_row3_col6 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_c6c86_row3_col7 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_c6c86_row4_col1, #T_c6c86_row5_col1, #T_c6c86_row7_col1 {
#   background-color: #3d50c3;
#   color: #f1f1f1;
# }
# #T_c6c86_row4_col5 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_c6c86_row5_col0 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_c6c86_row5_col3 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_c6c86_row5_col6 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_c6c86_row5_col7 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_c6c86_row6_col0 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_c6c86_row6_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_c6c86_row6_col4 {
#   background-color: #afcafc;
#   color: #000000;
# }
# #T_c6c86_row6_col5 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_c6c86_row6_col7 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_c6c86_row7_col0 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_c6c86_row7_col2 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_c6c86_row7_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_c6c86_row7_col4 {
#   background-color: #d5dbe5;
#   color: #000000;
# }
# #T_c6c86_row7_col5 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_c6c86_row7_col6 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c6c86_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >NVTA</th>
#       <th class="col_heading level0 col1" >AITX</th>
#       <th class="col_heading level0 col2" >TVTY</th>
#       <th class="col_heading level0 col3" >ERBB</th>
#       <th class="col_heading level0 col4" >UST</th>
#       <th class="col_heading level0 col5" >LUNA</th>
#       <th class="col_heading level0 col6" >SOL</th>
#       <th class="col_heading level0 col7" >LTC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6c86_level0_row0" class="row_heading level0 row0" >NVTA</th>
#       <td id="T_c6c86_row0_col0" class="data row0 col0" >0.002135</td>
#       <td id="T_c6c86_row0_col1" class="data row0 col1" >0.000382</td>
#       <td id="T_c6c86_row0_col2" class="data row0 col2" >0.000582</td>
#       <td id="T_c6c86_row0_col3" class="data row0 col3" >0.000051</td>
#       <td id="T_c6c86_row0_col4" class="data row0 col4" >-0.000027</td>
#       <td id="T_c6c86_row0_col5" class="data row0 col5" >0.000275</td>
#       <td id="T_c6c86_row0_col6" class="data row0 col6" >0.000280</td>
#       <td id="T_c6c86_row0_col7" class="data row0 col7" >0.000288</td>
#     </tr>
#     <tr>
#       <th id="T_c6c86_level0_row1" class="row_heading level0 row1" >AITX</th>
#       <td id="T_c6c86_row1_col0" class="data row1 col0" >0.000382</td>
#       <td id="T_c6c86_row1_col1" class="data row1 col1" >0.082759</td>
#       <td id="T_c6c86_row1_col2" class="data row1 col2" >0.000408</td>
#       <td id="T_c6c86_row1_col3" class="data row1 col3" >-0.000974</td>
#       <td id="T_c6c86_row1_col4" class="data row1 col4" >-0.000003</td>
#       <td id="T_c6c86_row1_col5" class="data row1 col5" >-0.000121</td>
#       <td id="T_c6c86_row1_col6" class="data row1 col6" >0.000564</td>
#       <td id="T_c6c86_row1_col7" class="data row1 col7" >-0.000226</td>
#     </tr>
#     <tr>
#       <th id="T_c6c86_level0_row2" class="row_heading level0 row2" >TVTY</th>
#       <td id="T_c6c86_row2_col0" class="data row2 col0" >0.000582</td>
#       <td id="T_c6c86_row2_col1" class="data row2 col1" >0.000408</td>
#       <td id="T_c6c86_row2_col2" class="data row2 col2" >0.001756</td>
#       <td id="T_c6c86_row2_col3" class="data row2 col3" >0.000012</td>
#       <td id="T_c6c86_row2_col4" class="data row2 col4" >-0.000023</td>
#       <td id="T_c6c86_row2_col5" class="data row2 col5" >0.000211</td>
#       <td id="T_c6c86_row2_col6" class="data row2 col6" >0.000214</td>
#       <td id="T_c6c86_row2_col7" class="data row2 col7" >0.000320</td>
#     </tr>
#     <tr>
#       <th id="T_c6c86_level0_row3" class="row_heading level0 row3" >ERBB</th>
#       <td id="T_c6c86_row3_col0" class="data row3 col0" >0.000051</td>
#       <td id="T_c6c86_row3_col1" class="data row3 col1" >-0.000974</td>
#       <td id="T_c6c86_row3_col2" class="data row3 col2" >0.000012</td>
#       <td id="T_c6c86_row3_col3" class="data row3 col3" >0.024070</td>
#       <td id="T_c6c86_row3_col4" class="data row3 col4" >-0.000055</td>
#       <td id="T_c6c86_row3_col5" class="data row3 col5" >0.000224</td>
#       <td id="T_c6c86_row3_col6" class="data row3 col6" >0.000081</td>
#       <td id="T_c6c86_row3_col7" class="data row3 col7" >-0.000125</td>
#     </tr>
#     <tr>
#       <th id="T_c6c86_level0_row4" class="row_heading level0 row4" >UST</th>
#       <td id="T_c6c86_row4_col0" class="data row4 col0" >-0.000027</td>
#       <td id="T_c6c86_row4_col1" class="data row4 col1" >-0.000003</td>
#       <td id="T_c6c86_row4_col2" class="data row4 col2" >-0.000023</td>
#       <td id="T_c6c86_row4_col3" class="data row4 col3" >-0.000055</td>
#       <td id="T_c6c86_row4_col4" class="data row4 col4" >0.000043</td>
#       <td id="T_c6c86_row4_col5" class="data row4 col5" >-0.000023</td>
#       <td id="T_c6c86_row4_col6" class="data row4 col6" >-0.000021</td>
#       <td id="T_c6c86_row4_col7" class="data row4 col7" >-0.000009</td>
#     </tr>
#     <tr>
#       <th id="T_c6c86_level0_row5" class="row_heading level0 row5" >LUNA</th>
#       <td id="T_c6c86_row5_col0" class="data row5 col0" >0.000275</td>
#       <td id="T_c6c86_row5_col1" class="data row5 col1" >-0.000121</td>
#       <td id="T_c6c86_row5_col2" class="data row5 col2" >0.000211</td>
#       <td id="T_c6c86_row5_col3" class="data row5 col3" >0.000224</td>
#       <td id="T_c6c86_row5_col4" class="data row5 col4" >-0.000023</td>
#       <td id="T_c6c86_row5_col5" class="data row5 col5" >0.001278</td>
#       <td id="T_c6c86_row5_col6" class="data row5 col6" >0.000190</td>
#       <td id="T_c6c86_row5_col7" class="data row5 col7" >0.000165</td>
#     </tr>
#     <tr>
#       <th id="T_c6c86_level0_row6" class="row_heading level0 row6" >SOL</th>
#       <td id="T_c6c86_row6_col0" class="data row6 col0" >0.000280</td>
#       <td id="T_c6c86_row6_col1" class="data row6 col1" >0.000564</t

# %%
# Copy the data into dataset df
df=return_data.copy()

# %%
# creating covariance table on stock return dataframe to store covariance results
#covariace measures how two variables are different/measures direction of relation between 2 variables
df_cov = df.cov()
print('Covariance Matrix:')
print(df_cov)
print('\n') # return/blank line

# create the average of every ticker, which become the coefficients of our objective function
df_return = df.mean()
# Printing the average return of the stocks
print('Average Return:')
print(df_return)
# Out:
# Covariance Matrix:
#           NVTA      AITX      TVTY      ERBB       UST      LUNA       SOL  \
# NVTA  0.002135  0.000382  0.000582  0.000051 -0.000027  0.000275  0.000280
# AITX  0.000382  0.082759  0.000408 -0.000974 -0.000003 -0.000121  0.000564
# TVTY  0.000582  0.000408  0.001756  0.000012 -0.000023  0.000211  0.000214
# ERBB  0.000051 -0.000974  0.000012  0.024070 -0.000055  0.000224  0.000081
# UST  -0.000027 -0.000003 -0.000023 -0.000055  0.000043 -0.000023 -0.000021
# LUNA  0.000275 -0.000121  0.000211  0.000224 -0.000023  0.001278  0.000190
# SOL   0.000280  0.000564  0.000214  0.000081 -0.000021  0.000190  0.002248
# LTC   0.000288 -0.000226  0.000320 -0.000125 -0.000009  0.000165  0.000119
#
#            LTC
# NVTA  0.000288
# AITX -0.000226
# TVTY  0.000320
# ERBB -0.000125
# UST  -0.000009
# LUNA  0.000165
# SOL   0.000119
# LTC   0.000408
#
#
# Average Return:
# NVTA    0.002494
# AITX    0.015903
# TVTY    0.001282
# ERBB    0.005454
# UST     0.000271
# LUNA    0.002391
# SOL     0.001263
# LTC     0.000332
# dtype: float64

# %%
df_cov
#covariance matrix output
# Out:
#           NVTA      AITX      TVTY      ERBB       UST      LUNA       SOL  \
# NVTA  0.002135  0.000382  0.000582  0.000051 -0.000027  0.000275  0.000280
# AITX  0.000382  0.082759  0.000408 -0.000974 -0.000003 -0.000121  0.000564
# TVTY  0.000582  0.000408  0.001756  0.000012 -0.000023  0.000211  0.000214
# ERBB  0.000051 -0.000974  0.000012  0.024070 -0.000055  0.000224  0.000081
# UST  -0.000027 -0.000003 -0.000023 -0.000055  0.000043 -0.000023 -0.000021
# LUNA  0.000275 -0.000121  0.000211  0.000224 -0.000023  0.001278  0.000190
# SOL   0.000280  0.000564  0.000214  0.000081 -0.000021  0.000190  0.002248
# LTC   0.000288 -0.000226  0.000320 -0.000125 -0.000009  0.000165  0.000119
#
#            LTC
# NVTA  0.000288
# AITX -0.000226
# TVTY  0.000320
# ERBB -0.000125
# UST  -0.000009
# LUNA  0.000165
# SOL   0.000119
# LTC   0.000408

# %% [markdown]
# ## Portfolio Optimization modeling

# %%
#define for portfolio optimization
from pyomo.environ import *
m = ConcreteModel()

# defining variables for all our tickers i.e. our stocks and cryptocurrencies
m.NVTA = Var(within=NonNegativeReals, bounds=(0,1))
m.AITX = Var(within=NonNegativeReals, bounds=(0,1))
m.TVTY = Var(within=NonNegativeReals, bounds=(0,1))
m.ERBB = Var(within=NonNegativeReals, bounds=(0,1))
m.UST = Var(within=NonNegativeReals, bounds=(0,1))
m.LUNA = Var(within=NonNegativeReals, bounds=(0,1))
m.SOL = Var(within=NonNegativeReals, bounds=(0,1))
m.LTC = Var(within=NonNegativeReals, bounds=(0,1))

# %%
#GOAL : Portfolio allocation strategy to distribute amount across stocks and cryptocurencies to get maximum value

# declare objective fuction to maximize returns
m.objective = Objective(expr =               
                        m.NVTA*df_return[0] + 
                        m.AITX*df_return[1] + 
                        m.TVTY*df_return[2] +
                        m.ERBB*df_return[3] + 
                        m.UST* df_return[4]+
                        m.LUNA*df_return[5] + 
                        m.SOL*df_return[6] + 
                        m.LTC*df_return[7], 
                        sense=maximize)


# declare constraints
# 1. Sum of all proportions = 1 i.e. we invest all of our money
m.sum_proportions = Constraint(expr = m.NVTA+m.AITX+m.TVTY+m.ERBB+m.UST+m.LUNA+m.SOL+m.LTC == 1)

# 2. Set lower limit for risk (to maximize profit)
m.total_risk = Constraint(expr = m.NVTA+m.AITX+m.TVTY+m.ERBB+m.UST+m.LUNA+m.SOL+m.LTC >= 0.0)

# %%
# creating calculations table for calculate the risk
#risk = Prop(A)Prop(B)Cov(A,B).
def calc_risk(m):
  variables = m.NVTA,m.AITX,m.TVTY,m.ERBB,m.UST,m.LUNA,m.SOL,m.LTC
  tickers = ['NVTA','AITX','TVTY','ERBB','UST','LUNA','SOL','LTC']
  risk_exp = 0
  for i in range(len(variables)):
    for j in range(len(variables)):
      risk_exp += variables[i]*df_cov.at[tickers[i],tickers[j]]*variables[j]
  return risk_exp

# We are going to use this expression to compute the risk
expr_risk = calc_risk(m)

#we tried different risk levels and arrived at 0.15 as our ideal max_risk level
max_risk = 0.15

# Sequence of risk levels
risk_limits = np.arange(0.001, max_risk, 0.0001) # take tiny steps
risk_limits
# Out:
# array([0.001 , 0.0011, 0.0012, ..., 0.1497, 0.1498, 0.1499])

# %%
np.count_nonzero(risk_limits)
#number of risk limits
# Out:
# 1490

# %%
from pyomo.opt import SolverStatus, TerminationCondition

# updating risk contraint for each limit and then solving the problem

param_analysis = {} # DICTIONARY :key=risk, value =stock allocations 
returns = {} # DICTIONARY : key=risk, value = return

#We solve optimizaiton problem for every risk limit
for r in risk_limits:
  # Remove previously defined total risk constraint to avoid error messages
  m.del_component(m.total_risk)
  #r here is risk limit from for loop
  m.total_risk = Constraint(expr = expr_risk <= r)
  # run solver
  result = SolverFactory('bonmin', executable='/content/bonmin').solve(m)

  # If solution is not feasible, ignore this run hence 'continue'
  #Filter out infeasible solutions
  if result.solver.termination_condition == TerminationCondition.infeasible:
    continue

  result = result.write()

  # store our allocation proportions
  param_analysis[r] = [m.NVTA(),m.AITX(),m.TVTY(),m.ERBB(),m.UST(),m.LUNA(),m.SOL(),m.LTC()]
  # store our returns
  returns[r] =  m.NVTA()*df_return[0] + m.AITX()*df_return[1] + m.TVTY()*df_return[2] +m.ERBB()*df_return[3] + m.UST()* df_return[4]+m.LUNA()*df_return[5] + m.SOL()*df_return[6] + m.LTC()*df_return[7]
# Out:
# Streaming output truncated to the last 5000 lines.
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03863382339477539
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.040975093841552734
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04114031791687012
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04384613037109375
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04266095161437988
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04183816909790039
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03909015655517578
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03800630569458008
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04730343818664551
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03912687301635742
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03475761413574219
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04423189163208008
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03691554069519043
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.036774635314941406
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03963804244995117
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03857612609863281
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04634380340576172
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.037816524505615234
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04217886924743652
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04566192626953125
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03941822052001953
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03701305389404297
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.040592193603515625
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03877902030944824
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.041777849197387695
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04490971565246582
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03737139701843262
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03704357147216797
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.0410618782043457
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.038353681564331055
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03506779670715332
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.037969350814819336
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04033708572387695
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.040960073471069336
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03722643852233887
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03715372085571289
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04130387306213379
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03647136688232422
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.0391695499420166
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04316449165344238
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03550910949707031
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.038460731506347656
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.035895347595214844
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.035730600357055664
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03917360305786133
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03787803649902344
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03891110420227051
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04221630096435547
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03976869583129883
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03897905349731445
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# ...
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04143095016479492
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.037490129470825195
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04212641716003418
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.042527198791503906
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04169750213623047
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03402900695800781
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.040450096130371094
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.037856101989746094
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.044777870178222656
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03820991516113281
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04302358627319336
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.0401151180267334
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03568601608276367
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.040042877197265625
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.040785789489746094
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.03813338279724121
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 8
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.039504289627075195
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %% [markdown]
# ## 2. Visualisation of optimal stock allocation

# %%
# generating the dataframe for proportions of the portfolio for each risk limit
# pareto chart : shows how much reward for risk
from matplotlib.pyplot import figure
figure(figsize=(1800, 2000), dpi=80)
param_analysis = pd.DataFrame.from_dict(param_analysis, orient='index')
param_analysis.columns = ['NVTA','AITX','TVTY','ERBB','UST','LUNA','SOL','LTC']
param_analysis.plot()
# Title and label of the graph
plt.title('PARETO CHART : Optimal Stock Allocation for Different Risk Levels')
plt.xlabel('Risk level')
plt.ylabel('Stock Allocation')
plt.show()
#we see that

# %% [markdown]
# CLOSER LOOK :

# %% [markdown]
# ![image.png]()![image.png](data:image/png;base64,...)

# %%
# subset
# Risk
risk = list(returns.keys()) #Dictionary values converetd to list
print(risk)
# Reward
reward = list(returns.values())#Dictionary values converetd to list
print(reward)
# Out:
# [0.001, 0.0011, 0.0012000000000000001, 0.0013000000000000002, 0.0014000000000000002, 0.0015000000000000002, 0.0016000000000000003, 0.0017000000000000003, 0.0018000000000000004, 0.0019000000000000004, 0.0020000000000000005, 0.0021000000000000003, 0.0022000000000000006, 0.002300000000000001, 0.0024000000000000007, 0.0025000000000000005, 0.0026000000000000007, 0.002700000000000001, 0.002800000000000001, 0.0029000000000000007, 0.003000000000000001, 0.003100000000000001, 0.003200000000000001, 0.003300000000000001, 0.003400000000000001, 0.0035000000000000014, 0.003600000000000001, 0.003700000000000001, 0.0038000000000000013, 0.0039000000000000016, 0.004000000000000002, 0.004100000000000001, 0.0042000000000000015, 0.004300000000000002, 0.004400000000000001, 0.004500000000000001, 0.004600000000000002, 0.004700000000000002, 0.004800000000000002, 0.004900000000000002, 0.005000000000000002, 0.005100000000000002, 0.005200000000000002, 0.005300000000000002, 0.005400000000000002, 0.005500000000000002, 0.005600000000000002, 0.005700000000000002, 0.005800000000000002, 0.0059000000000000025, 0.006000000000000003, 0.006100000000000002, 0.006200000000000002, 0.006300000000000003, 0.006400000000000002, 0.006500000000000002, 0.0066000000000000026, 0.006700000000000003, 0.006800000000000003
# %%
# plot! pylab makes it easy
from pylab import *
# The risk verses reward graph is plotted
plot(risk, reward, '-.')
#Title and label of the plot
title('The Efficient Frontier')
xlabel('Risk')
ylabel('Reward (Return)')
plt.show()

# %% [markdown]
# # Simulation Model

# %% [markdown]
# Based on the parato chart that we see above, we see that there are 4 assets that can be picked for a risk level of 0.005 or 0.0075 where the rest of the 4 assets go to 0 returns with increasing risks.
#
# The 4 assests that do not converge to a 0 returns at a risk of until 0.025 are the following
#
# ["NVTA","AITX","LUNA","ERBB"] are the aseets that are under consideration for the monte carlo simulation
#
# the objective of this simulation is to find the probability with which our portfolio with the chosen stock proportion will lose money

# %%
# retrieve covariance matrix from the previous steps
df_cov
# Out:
#           NVTA      AITX      TVTY      ERBB       UST      LUNA       SOL  \
# NVTA  0.002135  0.000382  0.000582  0.000051 -0.000027  0.000275  0.000280
# AITX  0.000382  0.082759  0.000408 -0.000974 -0.000003 -0.000121  0.000564
# TVTY  0.000582  0.000408  0.001756  0.000012 -0.000023  0.000211  0.000214
# ERBB  0.000051 -0.000974  0.000012  0.024070 -0.000055  0.000224  0.000081
# UST  -0.000027 -0.000003 -0.000023 -0.000055  0.000043 -0.000023 -0.000021
# LUNA  0.000275 -0.000121  0.000211  0.000224 -0.000023  0.001278  0.000190
# SOL   0.000280  0.000564  0.000214  0.000081 -0.000021  0.000190  0.002248
# LTC   0.000288 -0.000226  0.000320 -0.000125 -0.000009  0.000165  0.000119
#
#            LTC
# NVTA  0.000288
# AITX -0.000226
# TVTY  0.000320
# ERBB -0.000125
# UST  -0.000009
# LUNA  0.000165
# SOL   0.000119
# LTC   0.000408

# %%
# for the following list of ["NVTA","AITX","LUNA","ERBB"], we must subset the co-variance matrix from the main covariance matrix
df_cov_ss=df_cov.loc[["NVTA","AITX","LUNA","ERBB"],["NVTA","AITX","LUNA","ERBB"]]

# %%
# Display the first few records of the df_cov_ss table
df_cov_ss.head()
# Out:
#           NVTA      AITX      LUNA      ERBB
# NVTA  0.002135  0.000382  0.000275  0.000051
# AITX  0.000382  0.082759 -0.000121 -0.000974
# LUNA  0.000275 -0.000121  0.001278  0.000224
# ERBB  0.000051 -0.000974  0.000224  0.024070

# %%
import numpy as np

# %%
# convert the array to a list
risks_1=(risk_limits).tolist()
#print the list to observe the values of risk_levels(to see the exact value of risk levels that was considered in the previous step)
risks_1
# Out:
# [0.001,
#  0.0011,
#  0.0012000000000000001,
#  0.0013000000000000002,
#  0.0014000000000000002,
#  0.0015000000000000002,
#  0.0016000000000000003,
#  0.0017000000000000003,
#  0.0018000000000000004,
#  0.0019000000000000004,
#  0.0020000000000000005,
#  0.0021000000000000003,
#  0.0022000000000000006,
#  0.002300000000000001,
#  0.0024000000000000007,
#  0.0025000000000000005,
#  0.0026000000000000007,
#  0.002700000000000001,
#  0.002800000000000001,
#  0.0029000000000000007,
#  0.003000000000000001,
#  0.003100000000000001,
#  0.003200000000000001,
#  0.003300000000000001,
#  0.003400000000000001,
#  0.04180000000000002,
#  0.04190000000000002,
#  0.042000000000000016,
#  0.04210000000000002,
#  0.04220000000000002,
#  0.04230000000000002,
#  0.04240000000000002,
#  0.04250000000000002,
#  0.04260000000000002,
#  0.04270000000000002,
#  0.04280000000000002,
#  0.04290000000000002,
#  0.04300000000000002,
#  0.04310000000000002,
#  0.04320000000000002,
#  0.04330000000000002,
#  0.04340000000000002,
#  0.04350000000000002,
#  0.04360000000000002,
#  0.043700000000000024,
#  0.04380000000000002,
#  0.04390000000000002,
#  0.04400000000000002,
#  0.04410000000000002,
#  0.04420000000000002,
#  0.04430000000000002,
#  0.04440000000000002,
#  0.04450000000000002,
#  0.04460000000000002,
#  0.04470000000000002,
#  0.04480000000000002,
#  0.04490000000000002,
#  0.04500000000000002,
#  0.04510000000000002,
#  0.04520000000000002,
#  0.04530000000000002,
#  0.045400000000000024,
#  0.04550000000000002,
#  0.04560000000000002,
#  0.04570000000000002,
#  0.04580000000000002,
#  0.045900000000000024,
#  0.04600000000000002,
#  0.04610000000000002,
#  0.04620000000000002,
#  0.04630000000000002,
#  0.046400000000000025,
#  0.04650000000000002,
#  0.04660000000000002,
#  0.04670000000000002,
#  0.04680000000000002,
#  0.046900000000000025,
#  0.04700000000000002,
#  0.047100000000000024,
#  0.04720000000000002,
#  0.04730000000000002,
#  0.047400000000000025,
#  0.04750000000000002,
#  0.047600000000000024,
#  0.04770000000000002,
#  0.04780000000000002,
#  0.04790000000000002,
#  0.04800000000000002,
#  0.048100000000000025,
#  0.04820000000000002,
#  0.048300000000000023,
#  0.04840000000000002,
#  0.04850000000000002,
#  0.048600000000000025,
#  0.04870000000000002,
#  0.048800000000000024,
#  0.04890000000000002,
#  0.04900000000000002,
#  0.049100000000000026,
#  0.04920000000000002,
#  0.049300000000000024,
#  0.04940000000000002,
#  0.04950000000000002,
#  0.049600000000000026,
#  0.04970000000000002,
#  0.049800000000000025,
#  0.04990000000000002,
#  0.050000000000000024,
#  0.050100000000000026,
#  0.05020000000000002,
#  0.050300000000000025,
#  0.05040000000000002,
#  0.050500000000000024,
#  0.05060000000000002,
#  0.05070000000000002,
#  0.050800000000000026,
#  0.05090000000000002,
#  0.051000000000000024,
#  0.05110000000000002,
#  0.05120000000000002,
#  0.051300000000000026,
#  0.05140000000000002,
#  0.051500000000000025,
#  0.05160000000000002,
#  0.051700000000000024,
#  0.05180000000000003,
#  0.05190000000000002,
#  0.052000000000000025,
#  0.05210000000000002,
#  0.052200000000000024,
#  0.05230000000000003,
#  0.05240000000000002,
#  0.052500000000000026,
#  0.05260000000000002,
#  0.052700000000000025,
#  0.05280000000000003,
#  0.05290000000000002,
#  0.053000000000000026,
#  0.05310000000000002,
#  0.053200000000000025,
#  0.05330000000000003,
#  0.053400000000000024,
#  0.05350000000000003,
#  0.05360000000000002,
#  0.053700000000000025,
#  0.05380000000000003,
#  0.053900000000000024,
#  0.05400000000000003,
#  0.05410000000000002,
#  0.054200000000000026,
#  0.05430000000000002,
#  0.054400000000000025,
#  0.05450000000000003,
#  0.054600000000000024,
#  0.054700000000000026,
#  0.05480000000000002,
#  0.054900000000000025,
#  0.05500000000000003,
#  0.055100000000000024,
#  0.05520000000000003,
#  0.05530000000000002,
#  0.055400000000000026,
#  0.05550000000000003,
#  0.055600000000000024,
#  0.05570000000000003,
#  0.05580000000000002,
#  0.055900000000000026,
#  0.05600000000000003,
#  0.056100000000000025,
#  0.05620000000000003,
#  0.056300000000000024,
#  0.056400000000000027,
#  0.05650000000000003,
#  0.056600000000000025,
#  0.05670000000000003,
#  0.056800000000000024,
#  0.05690000000000003,
#  0.05700000000000002,
#  0.057100000000000026,
#  0.05720000000000003,
#  0.057300000000000025,
#  0.05740000000000003,
#  0.05750000000000002,
#  0.057600000000000026,
#  0.05770000000000003,
#  0.057800000000000025,
#  0.05790000000000003,
#  0.058000000000000024,
#  0.05810000000000003,
#  0.05820000000000003,
#  0.058300000000000025,
#  0.05840000000000003,
#  0.058500000000000024,
#  0.05860000000000003,
#  0.05870000000000003,
#  0.058800000000000026,
#  0.05890000000000003,
#  0.059000000000000025,
#  0.05910000000000003,
#  0.05920000000000003,
#  0.059300000000000026,
#  0.05940000000000003,
#  0.059500000000000025,
#  0.05960000000000003,
#  0.05970000000000003,
#  0.05980000000000003,
#  0.05990000000000003,
#  0.060000000000000026,
#  0.06010000000000003,
#  0.06020000000000003,
#  0.06030000000000003,
#  0.06040000000000003,
#  0.060500000000000026,
#  0.06060000000000003,
#  0.060700000000000025,
#  0.06080000000000003,
#  0.06090000000000003,
#  0.061000000000000026,
#  0.06110000000000003,
#  0.061200000000000025,
#  0.06130000000000003,
#  0.06140000000000003,
#  0.06150000000000003,
#  0.06160000000000003,
#  0.061700000000000026,
#  0.06180000000000003,
#  0.06190000000000003,
#  0.06200000000000003,
#  0.06210000000000003,
#  0.062200000000000026,
#  0.06230000000000003,
#  0.06240000000000003,
#  0.06250000000000003,
#  0.06260000000000003,
#  0.06270000000000002,
#  0.06280000000000002,
#  0.06290000000000003,
#  0.06300000000000003,
#  0.06310000000000003,
#  0.06320000000000002,
#  0.06330000000000002,
#  0.06340000000000003,
#  0.06350000000000003,
#  0.06360000000000003,
#  0.06370000000000003,
#  0.06380000000000002,
#  0.06390000000000003,
#  0.06400000000000003,
#  0.06410000000000003,
#  0.06420000000000003,
#  0.06430000000000002,
#  0.06440000000000003,
#  0.06450000000000003,
#  0.06460000000000003,
#  0.06470000000000004,
#  0.06480000000000002,
#  0.06490000000000003,
#  0.06500000000000003,
#  0.06510000000000003,
#  0.06520000000000004,
#  0.06530000000000002,
#  0.06540000000000003,
#  0.06550000000000003,
#  0.06560000000000003,
#  0.06570000000000004,
#  0.06580000000000003,
#  0.06590000000000003,
#  0.06600000000000003,
#  0.06610000000000003,
#  0.06620000000000004,
#  0.06630000000000003,
#  0.06640000000000003,
#  0.06650000000000003,
#  0.06660000000000003,
#  0.06670000000000004,
#  0.06680000000000003,
#  0.06690000000000003,
#  0.06700000000000003,
#  0.06710000000000003,
#  0.06720000000000004,
#  0.08010000000000003,
#  0.08020000000000004,
#  0.08030000000000004,
#  0.08040000000000004,
#  0.08050000000000004,
#  0.08060000000000003,
#  0.08070000000000004,
#  0.08080000000000004,
#  0.08090000000000004,
#  0.08100000000000004,
#  0.08110000000000003,
#  0.08120000000000004,
#  0.08130000000000004,
#  0.08140000000000004,
#  0.08150000000000003,
#  0.08160000000000003,
#  0.08170000000000004,
#  0.08180000000000004,
#  0.08190000000000004,
#  0.08200000000000003,
#  0.08210000000000003,
#  0.08220000000000004,
#  0.08230000000000004,
#  0.08240000000000004,
#  0.08250000000000003,
#  0.08260000000000003,
#  0.08270000000000004,
#  0.08280000000000004,
#  0.08290000000000004,
#  0.08300000000000003,
#  0.08310000000000003,
#  0.08320000000000004,
#  0.08330000000000004,
#  0.08340000000000004,
#  0.08350000000000003,
#  0.08360000000000004,
#  0.08370000000000004,
#  0.08380000000000004,
#  0.08390000000000004,
#  0.08400000000000003,
#  0.08410000000000004,
#  0.08420000000000004,
#  0.08430000000000004,
#  0.08440000000000004,
#  0.08450000000000003,
#  0.08460000000000004,
#  0.08470000000000004,
#  0.08480000000000004,
#  0.08490000000000004,
#  0.08500000000000003,
#  0.08510000000000004,
#  0.08520000000000004,
#  0.08530000000000004,
#  0.08540000000000005,
#  0.08550000000000003,
#  0.08560000000000004,
#  0.08570000000000004,
#  0.08580000000000004,
#  0.08590000000000005,
#  0.08600000000000003,
#  0.08610000000000004,
#  0.08620000000000004,
#  0.08630000000000004,
#  0.08640000000000005,
#  0.08650000000000004,
#  0.08660000000000004,
#  0.08670000000000004,
#  0.08680000000000004,
#  0.08690000000000005,
#  0.08700000000000004,
#  0.08710000000000004,
#  0.08720000000000004,
#  0.08730000000000004,
#  0.08740000000000003,
#  0.08750000000000004,
#  0.08760000000000004,
#  0.08770000000000004,
#  0.08780000000000004,
#  0.08790000000000003,
#  0.08800000000000004,
#  0.08810000000000004,
#  0.08820000000000004,
#  0.08830000000000005,
#  0.08840000000000003,
#  0.08850000000000004,
#  0.08860000000000004,
#  0.08870000000000004,
#  0.08880000000000005,
#  0.08890000000000003,
#  0.08900000000000004,
#  0.08910000000000004,
#  0.08920000000000004,
#  0.08930000000000005,
#  0.08940000000000003,
#  0.08950000000000004,
#  0.08960000000000004,
#  0.08970000000000004,
#  0.08980000000000005,
#  0.08990000000000004,
#  0.09000000000000004,
#  0.09010000000000004,
#  0.09020000000000004,
#  0.09030000000000005,
#  0.09040000000000004,
#  0.09050000000000004,
#  0.09060000000000004,
#  0.09070000000000004,
#  0.09080000000000005,
#  0.09090000000000004,
#  0.09100000000000004,
#  0.09110000000000004,
#  0.09120000000000004,
#  0.09130000000000005,
#  0.09140000000000004,
#  0.09150000000000004,
#  0.09160000000000004,
#  0.09170000000000005,
#  0.09180000000000005,
#  0.09190000000000004,
#  0.09200000000000004,
#  0.09210000000000004,
#  0.09220000000000005,
#  0.09230000000000005,
#  0.09240000000000004,
#  0.09250000000000004,
#  0.09260000000000004,
#  0.09270000000000005,
#  0.09280000000000005,
#  0.09290000000000004,
#  0.09300000000000004,
#  0.09310000000000004,
#  0.09320000000000005,
#  0.09330000000000005,
#  0.09340000000000004,
#  0.09350000000000004,
#  0.09360000000000004,
#  0.09370000000000005,
#  0.09380000000000005,
#  0.09390000000000004,
#  0.09400000000000004,
#  0.09410000000000004,
#  0.09420000000000005,
#  0.09430000000000004,
#  0.09440000000000004,
#  0.09450000000000004,
#  0.09460000000000005,
#  0.09470000000000005,
#  0.09480000000000004,
#  0.09490000000000004,
#  0.09500000000000004,
#  0.09510000000000005,
#  0.09520000000000005,
#  0.09530000000000004,
#  0.09540000000000004,
#  0.09550000000000004,
#  0.09560000000000005,
#  0.09570000000000005,
#  0.09580000000000004,
#  0.09590000000000004,
#  0.09600000000000004,
#  0.09610000000000005,
#  0.09620000000000005,
#  0.09630000000000004,
#  0.09640000000000004,
#  0.09650000000000004,
#  0.09660000000000005,
#  0.09670000000000005,
#  0.09680000000000004,
#  0.09690000000000004,
#  0.09700000000000004,
#  0.09710000000000005,
#  0.09720000000000005,
#  0.09730000000000004,
#  0.09740000000000004,
#  0.09750000000000004,
#  0.09760000000000005,
#  0.09770000000000005,
#  0.09780000000000004,
#  0.09790000000000004,
#  0.09800000000000005,
#  0.09810000000000005,
#  0.09820000000000005,
#  0.09830000000000004,
#  0.09840000000000004,
#  0.09850000000000005,
#  0.09860000000000005,
#  0.09870000000000005,
#  0.09880000000000004,
#  0.09890000000000004,
#  0.09900000000000005,
#  0.09910000000000005,
#  0.09920000000000005,
#  0.09930000000000004,
#  0.09940000000000004,
#  0.09950000000000005,
#  0.09960000000000005,
#  0.09970000000000005,
#  0.09980000000000004,
#  0.09990000000000004,
#  0.10000000000000005,
#  0.10010000000000005,
#  0.10020000000000004,
#  0.10030000000000004,
#  0.10040000000000004,
#  0.10050000000000005,
#  0.10060000000000005,
#  0.10070000000000004,
#  0.10080000000000004,
#  0.10090000000000005,
#  ...]

# %%
#0.007500000000000003 is closest risk values we had identified from the pareto chart
print(risks_1.index(0.007500000000000003))
print(risks_1.index(0.005500000000000002))
print(risks_1.index(0.01950000000000001))
# Out:
# 65
# 45
# 185

# %%
#retrieve the main returns value from the first part of the optimisation analysis
df_return
# Out:
# NVTA    0.002494
# AITX    0.015903
# TVTY    0.001282
# ERBB    0.005454
# UST     0.000271
# LUNA    0.002391
# SOL     0.001263
# LTC     0.000332
# dtype: float64

# %%
# to see if this risk value give us exactl 4 stocks with non-zero proportions
param_analysis.loc[0.007500000000000003]
# Out:
# NVTA    1.991376e-01
# AITX    2.702616e-01
# TVTY    1.464208e-10
# ERBB    2.313058e-01
# UST     0.000000e+00
# LUNA    2.992951e-01
# SOL     1.183497e-10
# LTC     0.000000e+00
# Name: 0.007500000000000003, dtype: float64

# %%
# subset the return values from the main dataframe
df_return.iloc[[0,1,5,3]]
# Out:
# NVTA    0.002494
# AITX    0.015903
# LUNA    0.002391
# ERBB    0.005454
# dtype: float64

# %%
## retreive the returns for the NVTA, AITX, ERBB and LUNA for a particular date and store it in a subset
df_return_ss=df_return.iloc[[0,1,5,3]]

# %% [markdown]
# ## Simulating % loss
#
# The following snippets of code were generated to check for the loss % for different values of risk levels.
#
# ---

# %%
# to retrieve the proportion of NVTA, AITX, ERBB and LUNA, we use the indices 0,1,3 and  and store it in n,a,e,l varaible
#let us fix the risk level to be [0.007500000000000003] since it shows the presence of 4 stocks and the rest of the 4 tends to 0 at this level
n=param_analysis.loc[0.007500000000000003][0]
a=param_analysis.loc[0.007500000000000003][1]
e=param_analysis.loc[0.007500000000000003][3]
l=param_analysis.loc[0.007500000000000003][5]

#n,a,e,l stores the proportion of assets for the chosen risk value

# %%
# run the simulation
simulations=100000
sum_of_returns=list()
#the loss_val is a counter that will increment everytime sum of return*proprotion for 4 chosen stocks is less than 1
# for the simulation, we need to get the value of return for each of the chosen asset 
# this is donw using the np multivariate function that takes into account the mean of returns and covariance for the assets to compute the values.
# the result of this function is a list of 4 asset value or return values 


loss_val=0 
for i in range(simulations):
  asset_list=np.random.multivariate_normal(df_return_ss,df_cov_ss)



# We are computing the investment value by taking the product of the returns and proportion of assets
# if this total investment value is less than 0, this implies we will lose money 

  value_asset=(asset_list[0]*n)+(asset_list[1]*a)+(asset_list[2]*l)+(asset_list[3]*e)
  sum_of_returns.append(value_asset)
  if(value_asset<0):
    loss_val+=1
  else:
    continue

loss_p=round((loss_val/simulations)*100,2)


print("The probability percentage of losing money in this portfolio for a risk of 0.007500000000000003 is:", loss_p,"%")
# Out:
# The probability percentage of losing money in this portfolio for a risk of 0.007500000000000003 is: 46.69 %

# %% [markdown]
# ## Density Plot Graph

# %%
# Displaying the density plot graph
sns.distplot(sum_of_returns)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Analysis

# %% [markdown]
# Analyze S&P 500 and Dow Jones Indices stock allocations
# Using the One risk level from the efficient frontier plot above, Create a table that shows the price of your stocks on the first day of each month from Jan 1, 2021 (when you would have done your allocation), Feb 1, 2021 ... through October 1, 2021 (when we imagine you sold your stocks) that comes from that risk level.
#
# **Looking at the efficient frontier from above, we do not have any gain in returns after a risk = 0.0006.** We are able to arrive at this conclusion as we set our max_risk = 0.0015, hence we set the same for analyzing the stocks from the S&P and Dow Jones indices as well.

# %%
#Scrapping monthly Stock data from Yahoo Finance from Jan 1 2021 to Oct 1, 2021

# Assign the ticker list that we want to scrap
#Stocks selected are 'NVTA','AITX','LUNA','ERBB'
tickers_list = ['NVTA','AITX','LUNA','ERBB']
# pull historical price data for each stocks to match with our news score later
sp_prices = {ticker : si.get_data(ticker,start_date = '01/01/2021',end_date='01/01/2022',interval='1mo') for ticker in tickers_list}

# %%
#see results
sp_prices
# Out:
# {'AITX':                open     high      low    close  adjclose      volume ticker
#  2021-01-01  0.03480  0.21000  0.02100  0.10900   0.10900  4678656175   AITX
#  2021-02-01  0.12995  0.28990  0.08100  0.13800   0.13800  2785156638   AITX
#  2021-03-01  0.15500  0.16000  0.08880  0.09250   0.09250  1468578236   AITX
#  2021-04-01  0.09200  0.11990  0.05000  0.10000   0.10000  1429210011   AITX
#  2021-05-01  35.090000  35.400002  25.240000  28.780001  28.780001   89059900
#  2021-06-01  28.980000  35.509998  26.950001  33.730000  33.730000   80972800
#  2021-07-01  33.619999  34.278000  26.020000  27.990000  27.990000   51156300
#  2021-08-01  28.190001  32.410000  24.160000  29.629999  29.629999   79055700
#  2021-09-01  29.780001  32.930000  28.219999  28.430000  28.430000   63654500
#  2021-10-01  28.430000  29.150000  25.690001  26.500000  26.500000   30747000
#  2021-11-01  26.500000  28.059999  16.790001  17.000000  17.000000   80377800
#  2021-12-01  17.100000  18.440001  14.060000  15.270000  15.270000   92347200
#
#             ticker
#  2021-01-01   NVTA
#  2021-02-01   NVTA
#  2021-03-01   NVTA
#  2021-04-01   NVTA
#  2021-05-01   NVTA
#  2021-06-01   NVTA
#  2021-07-01   NVTA
#  2021-08-01   NVTA
#  2021-09-01   NVTA
#  2021-10-01   NVTA
#  2021-11-01   NVTA
#  2021-12-01   NVTA  }

# %%
#extracting just the data we need
sp_prep = pd.DataFrame(sp_prices['NVTA']['adjclose']).rename(columns = {"adjclose":"NVTA"})

# combine all the tickers (all the rest of the samples)
for i in tickers_list[1:]:
  sp_prep[i] = pd.DataFrame(sp_prices[i]['adjclose'])
# Display the results
sp_prep
# Out:
#                  NVTA     AITX   LUNA     ERBB
# 2021-01-01  49.520000  0.10900  10.63  0.01200
# 2021-02-01  40.130001  0.13800  11.74  0.01170
# 2021-03-01  38.209999  0.09250  10.53  0.00950
# 2021-04-01  34.900002  0.10000  11.34  0.00830
# 2021-05-01  28.780001  0.06320  10.15  0.00625
# 2021-06-01  33.730000  0.05905  10.83  0.00560
# 2021-07-01  27.990000  0.04295  12.33  0.00390
# 2021-08-01  29.629999  0.04285  10.77  0.00540
# 2021-09-01  28.430000  0.03120   9.50  0.00420
# 2021-10-01  26.500000  0.03687   9.74  0.00360
# 2021-11-01  17.000000  0.02660   8.37  0.00285
# 2021-12-01  15.270000  0.01511   8.44  0.00250

# %%
# create return features for each ticker, 
# we will just use a pct_change as the return
return_sp = pd.DataFrame()
for i in tickers_list:
  return_sp[i] = sp_prep[i].pct_change()
# drop the na records
return_sp.dropna(inplace=True)
return_sp
# Out:
#                 NVTA      AITX      LUNA      ERBB
# 2021-02-01 -0.189620  0.266055  0.104421 -0.025000
# 2021-03-01 -0.047845 -0.329710 -0.103066 -0.188034
# 2021-04-01 -0.086626  0.081081  0.076923 -0.126316
# 2021-05-01 -0.175358 -0.368000 -0.104938 -0.246988
# 2021-06-01  0.171994 -0.065664  0.066995 -0.104000
# 2021-07-01 -0.170175 -0.272650  0.138504 -0.303571
# 2021-08-01  0.058592 -0.002328 -0.126521  0.384615
# 2021-09-01 -0.040499 -0.271879 -0.117920 -0.222222
# 2021-10-01 -0.067886  0.181731  0.025263 -0.142857
# 2021-11-01 -0.358491 -0.278546 -0.140657 -0.208333
# 2021-12-01 -0.101765 -0.431955  0.008363 -0.122807

# %%
#drop index to avoid issues while running model
return_sp.reset_index(drop=True, inplace=True)
return_sp
# Out:
#         NVTA      AITX      LUNA      ERBB
# 0  -0.189620  0.266055  0.104421 -0.025000
# 1  -0.047845 -0.329710 -0.103066 -0.188034
# 2  -0.086626  0.081081  0.076923 -0.126316
# 3  -0.175358 -0.368000 -0.104938 -0.246988
# 4   0.171994 -0.065664  0.066995 -0.104000
# 5  -0.170175 -0.272650  0.138504 -0.303571
# 6   0.058592 -0.002328 -0.126521  0.384615
# 7  -0.040499 -0.271879 -0.117920 -0.222222
# 8  -0.067886  0.181731  0.025263 -0.142857
# 9  -0.358491 -0.278546 -0.140657 -0.208333
# 10 -0.101765 -0.431955  0.008363 -0.122807

# %%
# creating covariance table on stock return dataframe
sp_cov = return_sp.cov()
print('Covariance Matrix:')
print(sp_cov)
print('\n') # return/blank line

# create the average of each stock
# these are the objective function COEFFICIENTS!
sp_return = return_sp.mean()
print('Average Return:')
print(sp_return)
# Out:
# Covariance Matrix:
#           NVTA      AITX      LUNA      ERBB
# NVTA  0.019128  0.006362  0.001423  0.011059
# AITX  0.006362  0.056893  0.011356  0.019317
# LUNA  0.001423  0.011356  0.010982 -0.003432
# ERBB  0.011059  0.019317 -0.003432  0.033717
#
#
# Average Return:
# NVTA   -0.091607
# AITX   -0.135624
# LUNA   -0.015694
# ERBB   -0.118683
# dtype: float64

# %%
# The S&P 500 values were extracted through the ticketer's list
tickers_list_SP = ['^GSPC']
# pull historical price data for S&P 500

dow_prices_SP = {ticker : si.get_data(ticker,start_date = '01/01/2021',end_date='01/01/2022',interval='1mo') for ticker in tickers_list_SP}
prep_data_SP = pd.DataFrame(dow_prices_SP['^GSPC']['adjclose']).rename(columns = {"adjclose":"^GSPC"})
prep_data_SP
# Out:
#                   ^GSPC
# 2021-01-01  3714.239990
# 2021-02-01  3811.149902
# 2021-03-01  3972.889893
# 2021-04-01  4181.169922
# 2021-05-01  4204.109863
# 2021-06-01  4297.500000
# 2021-07-01  4395.259766
# 2021-08-01  4522.680176
# 2021-09-01  4307.540039
# 2021-10-01  4605.379883
# 2021-11-01  4567.000000
# 2021-12-01  4766.180176

# %%
tickers_list_DJI = ['^DJI']
# pull historical price data for DowJones
dow_prices_DJI = {ticker : si.get_data(ticker,start_date = '01/01/2021',end_date='01/01/2022',interval='1mo') for ticker in tickers_list_DJI}
prep_data_DJI = pd.DataFrame(dow_prices_DJI['^DJI']['adjclose']).rename(columns = {"adjclose":"^DJI"})
prep_data_DJI
# Out:
#                     ^DJI
# 2021-01-01  29982.619141
# 2021-02-01  30932.369141
# 2021-03-01  32981.550781
# 2021-04-01  33874.851562
# 2021-05-01  34529.449219
# 2021-06-01  34502.511719
# 2021-07-01  34935.468750
# 2021-08-01  35360.730469
# 2021-09-01  33843.921875
# 2021-10-01  35819.558594
# 2021-11-01  34483.718750
# 2021-12-01  36338.300781

# %%
#Scrapping monthly Stock data from Yahoo Finance from Jan 1 2021 to Jan 1 2022

# Assign the ticker list that we want to scrap
tickers_list = ['NVTA','AITX','LUNA','ERBB','^GSPC','^DJI']
# pull historical price data for each stocks to match with our news score later
sp_prices = {ticker : si.get_data(ticker,start_date = '01/01/2021',end_date='01/01/2022',interval='1mo') for ticker in tickers_list}

# %%
sp_prep = pd.DataFrame(sp_prices['NVTA']['adjclose']).rename(columns = {"adjclose":"NVTA"})

# combine all the tickers (all the rest of the samples)
for i in tickers_list[1:]:
  sp_prep[i] = pd.DataFrame(sp_prices[i]['adjclose'])
#Display the results
sp_prep
# Out:
#                  NVTA     AITX   LUNA     ERBB        ^GSPC          ^DJI
# 2021-01-01  49.520000  0.10900  10.63  0.01200  3714.239990  29982.619141
# 2021-02-01  40.130001  0.13800  11.74  0.01170  3811.149902  30932.369141
# 2021-03-01  38.209999  0.09250  10.53  0.00950  3972.889893  32981.550781
# 2021-04-01  34.900002  0.10000  11.34  0.00830  4181.169922  33874.851562
# 2021-05-01  28.780001  0.06320  10.15  0.00625  4204.109863  34529.449219
# 2021-06-01  33.730000  0.05905  10.83  0.00560  4297.500000  34502.511719
# 2021-07-01  27.990000  0.04295  12.33  0.00390  4395.259766  34935.468750
# 2021-08-01  29.629999  0.04285  10.77  0.00540  4522.680176  35360.730469
# 2021-09-01  28.430000  0.03120   9.50  0.00420  4307.540039  33843.921875
# 2021-10-01  26.500000  0.03687   9.74  0.00360  4605.379883  35819.558594
# 2021-11-01  17.000000  0.02660   8.37  0.00285  4567.000000  34483.718750
# 2021-12-01  15.270000  0.01511   8.44  0.00250  4766.180176  36338.300781

# %%
#addd the value returns for the chose proportion of assets .
# a,n,e,l are the proporiton of assets for the chosen portfolio
sp_prep["NVTA_n"]=sp_prep["NVTA"]*n
sp_prep["AITX_a"]=sp_prep["AITX"]*a
sp_prep["LUNA_l"]=sp_prep["LUNA"]*l
sp_prep["ERBB_e"]=sp_prep["ERBB"]*e

# %%
sp_prep.drop(["NVTA","AITX","LUNA","ERBB"],axis=1,inplace=True)

# %%
sp_prep.rename(columns = {"NVTA_n":"NVTA","AITX_a":"AITX","LUNA_l":"LUNA","ERBB_e":"ERBB"},inplace=True)

# %%
# create return features for each ticker, 
# we will just use a pct_change as the return
return_sp = pd.DataFrame()
for i in tickers_list:
  return_sp[i] = sp_prep[i].pct_change()
# drop the na records
return_sp.dropna(inplace=True)
return_sp
# Out:
#                 NVTA      AITX      LUNA      ERBB     ^GSPC      ^DJI
# 2021-02-01 -0.189620  0.266055  0.104421 -0.025000  0.026091  0.031677
# 2021-03-01 -0.047845 -0.329710 -0.103066 -0.188034  0.042439  0.066247
# 2021-04-01 -0.086626  0.081081  0.076923 -0.126316  0.052425  0.027085
# 2021-05-01 -0.175358 -0.368000 -0.104938 -0.246988  0.005486  0.019324
# 2021-06-01  0.171994 -0.065664  0.066995 -0.104000  0.022214 -0.000780
# 2021-07-01 -0.170175 -0.272650  0.138504 -0.303571  0.022748  0.012549
# 2021-08-01  0.058592 -0.002328 -0.126521  0.384615  0.028990  0.012173
# 2021-09-01 -0.040499 -0.271879 -0.117920 -0.222222 -0.047569 -0.042895
# 2021-10-01 -0.067886  0.181731  0.025263 -0.142857  0.069144  0.058375
# 2021-11-01 -0.358491 -0.278546 -0.140657 -0.208333 -0.008334 -0.037294
# 2021-12-01 -0.101765 -0.431955  0.008363 -0.122807  0.043613  0.053781

# %%
#drop index to avoid issues while running model
return_sp.reset_index(drop=True, inplace=True)
return_sp
# Out:
#         NVTA      AITX      LUNA      ERBB     ^GSPC      ^DJI
# 0  -0.189620  0.266055  0.104421 -0.025000  0.026091  0.031677
# 1  -0.047845 -0.329710 -0.103066 -0.188034  0.042439  0.066247
# 2  -0.086626  0.081081  0.076923 -0.126316  0.052425  0.027085
# 3  -0.175358 -0.368000 -0.104938 -0.246988  0.005486  0.019324
# 4   0.171994 -0.065664  0.066995 -0.104000  0.022214 -0.000780
# 5  -0.170175 -0.272650  0.138504 -0.303571  0.022748  0.012549
# 6   0.058592 -0.002328 -0.126521  0.384615  0.028990  0.012173
# 7  -0.040499 -0.271879 -0.117920 -0.222222 -0.047569 -0.042895
# 8  -0.067886  0.181731  0.025263 -0.142857  0.069144  0.058375
# 9  -0.358491 -0.278546 -0.140657 -0.208333 -0.008334 -0.037294
# 10 -0.101765 -0.431955  0.008363 -0.122807  0.043613  0.053781

# %%
# create the performance report for the returns value
assets_returns_1=return_sp[["NVTA","AITX","ERBB","LUNA"]].sum().sum()
sp_ret=return_sp["^GSPC"].sum()
dj_ret=return_sp["^DJI"].sum()
performance_report = pd.DataFrame({'Returns':[sp_ret,dj_ret,assets_returns_1]}, index=["S&P 500","Dow Jones","Portfolio Chosen" ])
performance_report
# Out:
#                    Returns
# S&P 500           0.257248
# Dow Jones         0.200241
# Portfolio Chosen -3.977691

# %% [markdown]
# The chosen portfolio was then compared with the % returns from S&P 500 and Dow Jones. The S&P 500 shows a return of 0.257 and Dow Jones of 0.20. However we see that portfolio we chose with a proportion of
# 0.199 NVTA, 0.270 AITX, 0.299 LUNA and 0.233 of ERBB, has a comparitvely higher negative returns for the year 2021.Thus implying that an investment in this chosen portfolio could lead to a loss of money compared to investing in S&P 500 or Dow Jones.

# %%
# creating covariance table on stock return dataframe
sp_cov = return_sp.cov()
# Printing the covariance matrix
print('Covariance Matrix:')
print(sp_cov)
print('\n') # return/blank line

# create the average of each stock
# these are the objective function COEFFICIENTS!
sp_return = return_sp.mean()
# Printing the average return
print('Average Return:')
print(sp_return)
# Out:
# Covariance Matrix:
#            NVTA      AITX      LUNA      ERBB     ^GSPC      ^DJI
# NVTA   0.019128  0.006362  0.001423  0.011059  0.000851  0.000755
# AITX   0.006362  0.056893  0.011356  0.019317  0.003132  0.001486
# LUNA   0.001423  0.011356  0.010982 -0.003432  0.001571  0.001205
# ERBB   0.011059  0.019317 -0.003432  0.033717  0.001293  0.000563
# ^GSPC  0.000851  0.003132  0.001571  0.001293  0.001011  0.000984
# ^DJI   0.000755  0.001486  0.001205  0.000563  0.000984  0.001269
#
#
# Average Return:
# NVTA    -0.091607
# AITX    -0.135624
# LUNA    -0.015694
# ERBB    -0.118683
# ^GSPC    0.023386
# ^DJI     0.018204
# dtype: float64

# %% [markdown]
# Optimization model with atleast 2 stocks receiving atleast 10% of budget each

# %% [markdown]
# Objective Function:
#
# Max(Z) = NVTA * A1 + AITX* A2 + TVTY * A3 + ERBB * A4 + UST * A5 + LUNA * A6 + SOL * A7 + LTC * A8
#
# Constraints:
#
# Sum of all proportions = 1
#
# NVTA+AITX+TVTY+ERBB+UST+LUNA+SOL+LTC = 1
#
# At least 2 stocks should have more than 10% of the budget
#
# A1+A2+A3+A4+A5+A6+A7+A8>=2
#
# Each stock having atleast 10% if it is present
#
# NVTA >= 0.1*A1
#
# AITX >= 0.1*A2
#
# TVTY >= 0.1*A3
#
# ERBB >= 0.1*A4
#
# UST >= 0.1*A5
#
# LUNA >= 0.1*A6
#
# SOL >= 0.1*A7
#
# LTC>= 0.1*A8

# %%
# Optimization model with atleast 2 stocks receiving atleast 10% of budget each
from pyomo.environ import *
budget = 1

# Defining the model
m = ConcreteModel()

# defining the different stocks as variables
m.NVTA = Var(within=NonNegativeReals, bounds=(0,1))
m.AITX = Var(within=NonNegativeReals, bounds=(0,1))
m.TVTY = Var(within=NonNegativeReals, bounds=(0,1))
m.ERBB = Var(within=NonNegativeReals, bounds=(0,1))
m.UST = Var(within=NonNegativeReals, bounds=(0,1))
m.LUNA = Var(within=NonNegativeReals, bounds=(0,1))
m.SOL = Var(within=NonNegativeReals, bounds=(0,1))
m.LTC = Var(within=NonNegativeReals, bounds=(0,1))

# Defining the binary variables for every stock. 
# If the value is 0, then the stock doesnot receive  atleast 10% of budget
# If the value is 1, then the stock receives  atleast 10% of budget
m.A1 = Var(domain=Binary) # Binary Variable for NVTA
m.A2 = Var(domain=Binary) # Binary Variable for AITX
m.A3 = Var(domain=Binary) # Binary Variable for TVTY
m.A4 = Var(domain=Binary) # Binary Variable for ERBB
m.A5 = Var(domain=Binary) # Binary Variable for UST
m.A6 = Var(domain=Binary) # Binary Variable for LUNA
m.A7 = Var(domain=Binary) # Binary Variable for SOL
m.A8 = Var(domain=Binary) # Binary Variable for LTC

# %%
# Objective Function Max(Z) = NVTA * A1 + AITX* A2 + TVTY * A3 + ERBB * A4 + UST * A5 + LUNA * A6 + SOL * A7 + LTC * A8
m.objective = Objective(expr =               
                        m.NVTA*df_return[0] + 
                        m.AITX*df_return[1] + 
                        m.TVTY*df_return[2] +
                        m.ERBB*df_return[3] + 
                        m.UST* df_return[4]+
                        m.LUNA*df_return[5] + 
                        m.SOL*df_return[6] + 
                        m.LTC*df_return[7], 
                        sense=maximize) # yes, we want to MAX our returns!

# declare constraints
# 1. Sum of all proportions = 1
m.sum_proportions = Constraint(expr = m.NVTA+m.AITX+m.TVTY+m.ERBB+m.UST+m.LUNA+m.SOL+m.LTC == 1)


# 2. At least 2 stocks should have more than 10% of the budget
m.Constraint1 = Constraint(expr = m.A1+m.A2+m.A3+m.A4+m.A5+m.A6+m.A7+m.A8>=2)

#3 Since atleast 2 stocks should have alteast 10 % budget, we add the constraint to every stock 
# NVTA >= 0.1*A1
m.Constraint2 = Constraint(expr =m.NVTA>=0.1*m.A1)
# AITX >= 0.1*A2
m.Constraint3 = Constraint(expr =m.AITX>=0.1*m.A2)
# TVTY >= 0.1*A3
m.Constraint4 = Constraint(expr =m.TVTY>=0.1*m.A3)
# ERBB >= 0.1*A4
m.Constraint5 = Constraint(expr =m.ERBB>=0.1*m.A4)
# UST >= 0.1*A5
m.Constraint6 = Constraint(expr =m.UST>=0.1*m.A5)
# LUNA >= 0.1*A6
m.Constraint7 = Constraint(expr =m.LUNA>=0.1*m.A6)
# SOL >= 0.1*A7
m.Constraint8 = Constraint(expr =m.SOL>=0.1*m.A7)
# LTC>= 0.1*A8
m.Constraint9 = Constraint(expr =m.LTC>=0.1*m.A8)

# 3. Set maximum risk: WE ARE INCLUDING THIS CONSTRAINT NOW FOR TECHNICAL REASONS (see below), YOU CAN (and should!) IGNORE IT FOR NOW!
m.total_risk = Constraint(expr = m.NVTA+m.AITX+m.TVTY+m.ERBB+m.UST+m.LUNA+m.SOL+m.LTC >= 0.0)

# %%
# creating calculations table for calculate the risk
# 3. Calculate risk
def calc_risk(m):
  variables = m.NVTA,m.AITX,m.TVTY,m.ERBB,m.UST,m.LUNA,m.SOL,m.LTC
  tickers = ['NVTA','AITX','TVTY','ERBB','UST','LUNA','SOL','LTC']
  risk_exp = 0
  for i in range(len(variables)):
    for j in range(len(variables)):
      risk_exp += variables[i]*df_cov.at[tickers[i],tickers[j]]*variables[j]
  return risk_exp

# We are going to use this expression to compute the risk
expr_risk = calc_risk(m)

# 3. Max risk should be less than 0.01
max_risk = 0.15
# Sequence of risk levels
risk_limits = np.arange(0.001, max_risk, 0.0001) # take tiny steps
risk_limits
# Out:
# array([0.001 , 0.0011, 0.0012, ..., 0.1497, 0.1498, 0.1499])

# %%
from pyomo.opt import SolverStatus, TerminationCondition

# updating risk contraint for each limit and then solving the problem
param_analysis = {} # key=risk, value =stock allocations 
returns = {} # key=risk, value = return
for r in risk_limits:
  # Remove constraint to avoid error messages
  m.del_component(m.total_risk)
  m.total_risk = Constraint(expr = expr_risk <= r)
  # run solver
  result = SolverFactory('bonmin', executable='/content/bonmin').solve(m)

  # If solution is not feasible, ignore this run
  if result.solver.termination_condition == TerminationCondition.infeasible:
    continue

  result = result.write()

  # store our allocation proportions
  param_analysis[r] = [m.NVTA(),m.AITX(),m.TVTY(),m.ERBB(),m.UST(),m.LUNA(),m.SOL(),m.LTC()]
  # store our returns
  returns[r] =  m.NVTA()*df_return[0] + m.AITX()*df_return[1] + m.TVTY()*df_return[2] +m.ERBB()*df_return[3] + m.UST()* df_return[4]+m.LUNA()*df_return[5] + m.SOL()*df_return[6] + m.LTC()*df_return[7]
# Out:
# Streaming output truncated to the last 5000 lines.
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.057904958724975586
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04912161827087402
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05071616172790527
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.060041189193725586
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05091524124145508
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.047411441802978516
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.054509639739990234
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04627847671508789
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.047112226486206055
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.046677589416503906
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05151677131652832
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.053647518157958984
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05529284477233887
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04944872856140137
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05684328079223633
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04863905906677246
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04690217971801758
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.054505109786987305
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04970383644104004
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05737662315368652
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04904985427856445
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.049405574798583984
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.0510861873626709
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04694056510925293
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04789590835571289
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.055039167404174805
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.0495145320892334
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.048157691955566406
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.047617435455322266
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05536842346191406
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.045838117599487305
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04798316955566406
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05057573318481445
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05863308906555176
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05082559585571289
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05816650390625
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.0490725040435791
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.0499720573425293
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.058127641677856445
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.050867319107055664
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.050617218017578125
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.052355051040649414
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05404019355773926
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.053310394287109375
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04792666435241699
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.049800872802734375
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04873847961425781
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05360913276672363
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05364060401916504
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05210280418395996
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
# ...
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.047409772872924805
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.055356502532958984
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04829120635986328
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05699920654296875
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05592679977416992
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04648184776306152
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04697823524475098
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05288052558898926
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.046262264251708984
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05454897880554199
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04945802688598633
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05784153938293457
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04920148849487305
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.051018476486206055
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04825735092163086
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.04757237434387207
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0
# # ==========================================================
# # = Solver Results                                         =
# # ==========================================================
# # ----------------------------------------------------------
# #   Problem Information
# # ----------------------------------------------------------
# Problem:
# - Lower bound: -inf
#   Upper bound: inf
#   Number of objectives: 1
#   Number of constraints: 0
#   Number of variables: 16
#   Sense: unknown
# # ----------------------------------------------------------
# #   Solver Information
# # ----------------------------------------------------------
# Solver:
# - Status: ok
#   Message: bonmin\x3a Optimal
#   Termination condition: optimal
#   Id: 3
#   Error rc: 0
#   Time: 0.05654191970825195
# # ----------------------------------------------------------
# #   Solution Information
# # ----------------------------------------------------------
# Solution:
# - number of solutions: 0
#   number of solutions displayed: 0

# %%
# Print the results of the model
m.pprint()
# Out:
# 16 Var Declarations
#     A1 : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   0.0 :     1 : False : False : Binary
#     A2 : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   1.0 :     1 : False : False : Binary
#     A3 : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   0.0 :     1 : False : False : Binary
#     A4 : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   1.0 :     1 : False : False : Binary
#     A5 : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   0.0 :     1 : False : False : Binary
#     A6 : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   0.0 :     1 : False : False : Binary
#     A7 : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   0.0 :     1 : False : False : Binary
#     A8 : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   0.0 :     1 : False : False : Binary
#     AITX : Size=1, Index=None
#         Key  : Lower : Value              : Upper : Fixed : Stale : Domain
#         None :     0 : 0.9000000607733359 :     1 : False : False : NonNegativeReals
#     ERBB : Size=1, Index=None
#         Key  : Lower : Value               : Upper : Fixed : Stale : Domain
#         None :     0 : 0.09999999095704329 :     1 : False : False : NonNegativeReals
#     LTC : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   0.0 :     1 : False : False : NonNegativeReals
#     LUNA : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   0.0 :     1 : False : False : NonNegativeReals
#     NVTA : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   0.0 :     1 : False : False : NonNegativeReals
#     SOL : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   0.0 :     1 : False : False : NonNegativeReals
#     TVTY : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   0.0 :     1 : False : False : NonNegativeReals
#     UST : Size=1, Index=None
#         Key  : Lower : Value : Upper : Fixed : Stale : Domain
#         None :     0 :   0.0 :     1 : False : False : NonNegativeReals
#
# 1 Objective Declarations
#     objective : Size=1, Index=None, Active=True
#         Key  : Active : Sense    : Expression
#         None :   True : maximize : 0.0024941329259500337*NVTA + 0.01590289168979404*AITX + 0.001282211989237558*TVTY + 0.005454047993118546*ERBB + 0.0002706179911456847*UST + 0.002390770157488066*LUNA + 0.0012634203287611217*SOL + 0.00033162078228502276*LTC
#
# 11 Constraint Declarations
#     Constraint1 : Size=1, Index=None, Active=True
#         Key  : Lower : Body                                  : Upper : Active
#         None :   2.0 : A1 + A2 + A3 + A4 + A5 + A6 + A7 + A8 :  +Inf :   True
#     Constraint2 : Size=1, Index=None, Active=True
#         Key  : Lower : Body          : Upper : Active
#         None :  -Inf : 0.1*A1 - NVTA :   0.0 :   True
#     Constraint3 : Size=1, Index=None, Active=True
#         Key  : Lower : Body          : Upper : Active
#         None :  -Inf : 0.1*A2 - AITX :   0.0 :   True
#     Constraint4 : Size=1, Index=None, Active=True
#         Key  : Lower : Body          : Upper : Active
#         None :  -Inf : 0.1*A3 - TVTY :   0.0 :   True
#     Constraint5 : Size=1, Index=None, Active=True
#         Key  : Lower : Body          : Upper : Active
#         None :  -Inf : 0.1*A4 - ERBB :   0.0 :   True
#     Constraint6 : Size=1, Index=None, Active=True
#         Key  : Lower : Body         : Upper : Active
#         None :  -Inf : 0.1*A5 - UST :   0.0 :   True
#     Constraint7 : Size=1, Index=None, Active=True
#
# 28 Declarations: NVTA AITX TVTY ERBB UST LUNA SOL LTC A1 A2 A3 A4 A5 A6 A7 A8 objective sum_proportions Constraint1 Constraint2 Constraint3 Constraint4 Constraint5 Constraint6 Constraint7 Constraint8 Constraint9 total_risk

# %%
# Display the profit
print("Returns = ", m.objective())
# Display the proportion of the stock if it is activated or not. 
# If activation = 0, then the stock is not activated
# If activation  = 1, then the stock is activated

# Proportion and activation of NVTA
print("Proportion of Stock NVTA = ", m.NVTA(), ", activation = ",m.A1())
# Proportion and activation of AITX
print("Proportion of Stock AITX = ", m.AITX(), ", activation = ",m.A2())
# Proportion and activation of TVTY
print("Proportion of Stock TVTY = ", m.TVTY(), ", activation = ",m.A3())
# Proportion and activation of ERBB
print("Proportion of Stock ERBB = ", m.ERBB(), ", activation = ",m.A4())
# Proportion and activation of UST
print("Proportion of Stock UST = ", m.UST(), ", activation = ",m.A5())
# Proportion and activation of LUNA
print("Proportion of Stock LUNA = ", m.LUNA(), ", activation = ",m.A6())
# Proportion and activation of SOL
print("Proportion of Stock SOL = ", m.SOL(), ", activation = ",m.A7())
# Proportion and activation of LTC
print("Proportion of Stock LTC = ", m.LTC(), ", activation = ",m.A8())
# Out:
# Returns =  0.014858008237277549
# Proportion of Stock NVTA =  0.0 , activation =  0.0
# Proportion of Stock AITX =  0.9000000607733359 , activation =  1.0
# Proportion of Stock TVTY =  0.0 , activation =  0.0
# Proportion of Stock ERBB =  0.09999999095704329 , activation =  1.0
# Proportion of Stock UST =  0.0 , activation =  0.0
# Proportion of Stock LUNA =  0.0 , activation =  0.0
# Proportion of Stock SOL =  0.0 , activation =  0.0
# Proportion of Stock LTC =  0.0 , activation =  0.0

# %%
# generating the dataframe for proportions of the portfolio for each risk limit
from matplotlib.pyplot import figure
# Size of the graph
figure(figsize=(1800, 2000), dpi=80)
# Plotting the graph
param_analysis = pd.DataFrame.from_dict(param_analysis, orient='index')
param_analysis.columns = ['NVTA','AITX','TVTY','ERBB','UST','LUNA','SOL','LTC']
param_analysis.plot()
# Title and label of the graph
plt.title('PARETO CHART : Optimal Stock Allocation for Different Risk Levels')
plt.xlabel('Risk level')
plt.ylabel('Stock Allocation')
# Displaying the graph
plt.show()

# %%
# List of the risk and reward
# Risk
risk = list(returns.keys()) # coerce dict_keys to a list
print(risk)
# Reward
reward = list(returns.values()) # coerce dict_values to a list
print(reward) # we aren't allowed to name our value 'return' - this is a reserved name.
# Out:
# [0.001, 0.0011, 0.0012000000000000001, 0.0013000000000000002, 0.0014000000000000002, 0.0015000000000000002, 0.0016000000000000003, 0.0017000000000000003, 0.0018000000000000004, 0.0019000000000000004, 0.0020000000000000005, 0.0021000000000000003, 0.0022000000000000006, 0.002300000000000001, 0.0024000000000000007, 0.0025000000000000005, 0.0026000000000000007, 0.002700000000000001, 0.002800000000000001, 0.0029000000000000007, 
296068, 0.00868822039291638, 0.008709389948952786, 0.008730485646637998, 0.008751508253671537, 0.008772458524545427, 0.008793337200859742, 0.008814145011628709, 0.008834882673581866, 0.008855550891443877, 0.008876150358215755, 0.008896681755451935, 0.008917145753521847, 0.008937543011865471, 0.008957874179242367, 0.008978139893973967, 0.008998340784179593, 0.009018477468006445, 0.009038550553853848, 0.009058560640591802, 0.009078508317761785, 0.009098394165786576, 0.009118218756142289, 0.009137982651520844, 0.00915768640594761, 0.009177330564834805, 0.009196915653027495, 0.009216442233903463, 0.009235910926709879, 0.009255322270962192, 0.009274676041132619, 0.009293973677870788, 0.009313215132766407, 0.009332401220361204, 0.00935153227423632, 0.009370608765271514, 0.009389631157669713, 0.009408599909088804, 0.009427515470769332, 0.009446378287661455, 0.00946518879854273, 0.009483947436223 ...

# %% [markdown]
# Because of the constraints, our model selected atleast 2 stocks (AITX and ERBB) by allocating the budget (0.9 and 0.099) to each one respectively.
#
# The pareto chart for this model clearly shows that we have two stocks namely AITX, ERBB because both of these stocks shows a stagnant return beyond a risk level of 0.06.

# %%
# plot! pylab makes it easy
from pylab import *
# Plotting the graph
plot(risk, reward, '-.')
# Title and label of the graph
title('The Efficient Frontier')
xlabel('Risk')
ylabel('Reward (Return)')
# Displaying the graph
plt.show()

# %% [markdown]
# # Conclusion

# %% [markdown]
# * As a team, we had selected stocks with market cap of less than 2 billion dollars and a crypotocurrency market cap of 20 billion - 40 billion dollars. Out of the chosen cryptocurrencies, UST and LCT were chosen out of our required Market Cap bracket, since we had unsatisfactory data for the rest of the Cryptocurrencies fitting the Market cap. Crpotocurrencies like HEX,ADA,XRP had one-non null value, too many missing values and issues with extraction for the given time stamp respectively.Hence we had to drop them from our list.
#
#
# * In order to select a portfolio that distributes our investment amount optimally across stocks and cryptocurencies to get maximum returns, we performed the optimization and computed the proportions for each of the assets. At a risk value between 0.005 and above and below 0.026, we were able to identify 4 stocks and cryptocurrencies that gave us non-zero returns for different risk levels. These assets that gave use returns for risk levels between 0.005-0.026 were NVTA,AITX,ERBB and LUNA
#
# * A portfolio was selected by considering a risk level of 007500000000000003, less aggressive one. The chosen portfolio has a proportion of 0.199 of NVTA, 0.270 of AITX, 0.299 of LUNA and 0.233 of ERBB.  The probability with which our portfolio lost money was computed by running a Monte Carlo Model with 100000 simulations.This simulation showed that our portfolio had a probability percentage 46.85% to lose money.
#
# * The chosen portfolio was then compared with the % returns from S&P 500 and Dow Jones and it was observed that this portfolio had a compartively higher negative returns for the year 2021.Thus implying that an investment in this chosen portfolio could lead to a loss of money compared to investing in S&P 500 or Dow Jones.
#
# * We built an optimization model with the constraints of choosing atleast 2 stocks for the portfolio and with a budget allocation of 10% to each of them. The results for the model showed that the returns were at a  0.014858, AITX with a proportion of 0.9001 and ERBB with a proportion of 0.099. The new portfolio allocation from integer programming has majority of AITX stocks since the returns are fairly higher compared to the other stocks. The plateau in the pareto chart for this model clearly have two stocks namely AITX, ERBB. Both these stocks shows a stagnant returns beyond a risk level of 0.06. The value of returns for this portfolio diminishes with an increase in the risk level as shown in the efficient frontier graph.
